# %%
# Circuit parameters
id = 20e-6
Vth = 0.271 # Estimated / computed

# Oxyde capacitance
cox_nmos = 8.30e-3 # fF/um2
cox_pmos = 8.16e-3 # fF/um2 

# Carrier mobility
cm_nFET = 0.03 # V^-1
cm_pFET = 0.01 # V^-1

# %%
import math

k = cm_nFET * cox_nmos * (12/5)
Vov = math.sqrt(2 * id / k)
Vgs = Vth + Vov

print(Vgs, Vov)
# Out:
# 0.529716841902111 0.25871684190211097
